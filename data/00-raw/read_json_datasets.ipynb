# %%
import pandas as pd
import json

# %%
pd.read_json("darko_raw.json")
# Out:
#         age  box_ddpm  box_odpm  d_dpm  d_dpm_rank   dpm  dpm_rank   nba_id  \
# 0      36.1     -0.35      1.49  -0.60         299  0.46        71        2
# 1      31.1     -0.17     -0.89  -0.14         162 -0.99       179        3
# 2      38.0     -0.49     -2.36  -0.47         256 -2.90       406        7
# 3      35.7     -0.54     -1.44  -0.53         275 -2.02       302        9
# 4      27.3     -0.52     -1.22  -0.52         273 -1.72       263       12
# ...     ...       ...       ...    ...         ...   ...       ...      ...
# 15019  24.2      0.90     -1.87   0.89         104 -0.97       308  1643024
# 15020  23.9     -0.36     -2.27  -0.36         414 -2.63       615  1643047
# 15021  23.7     -0.09     -1.73  -0.09         316 -1.83       478  1643052
# 15022  22.8     -0.33     -3.06  -0.34         409 -3.39       666  1643133
# 15023  24.6     -0.43     -2.00  -0.43         449 -2.44       595  1643141
#
# ...

# %%
pd.read_json("raptor_raw.json")
# Out:
#        d_raptor_rank    mp     nba_id  o_raptor_rank  player_id  \
# 0                131   959  abdelal01            220  abdelal01
# 1                256  1379  abdelal01            225  abdelal01
# 2                  4  3483  abdulka01              1  abdulka01
# 3                  3  2399  abdulka01              6  abdulka01
# 4                  8  3524  abdulka01             10  abdulka01
# ...              ...   ...        ...            ...        ...
# 12495            212  1082    1627790            269  zizican01
# 12496             49  1079    1627826            281  zubaciv01
# 12497             12  1646    1627826             76  zubaciv01
# 12498             32  1910    1627826            205  zubaciv01
# 12499            115  1852    1627826            200  zubaciv01
#
#                player_name  poss  raptor_defense  raptor_offense  raptor_rank  \
# 0           Alaa Abdelnaby  1998            -0.2            -2.6          210
# ...
